# %% [markdown]
# # Exercise 1
#
# Write a module that provides the following conversions:
#
# - Length - feet (') and inches ('') to meters (m)
# - Mass - pounds (lbs) to kilograms (kg)
# - Temperature - Kelvin (K) to Celsius (oC)
# - Time - hours (h) and minutes(m) to seconds (s)
#
# Each calculation should be within its own function, with the module, so you will write eight functions altogether. Write a program that provides a suitable menu system for your conversion functions. This program should import the module and access the functions (functions should not be defined in the same file as the user interface). You will need to carefully consider how the user enters information and the upper and lower bounds (valid range) for each type of conversion. For example, the temperature cannot go below 0o Kelvin.

# %%
# %run conversions.ipynb  # Notebook analogue to import

options = {'1': ft_to_m, 
           '2': lbs_to_kg, 
           '3': kelvin_to_centigrade, 
           '4': h_m_to_sec}

while True:
    print("""1. Feet to Meter
2. Pound to Kilo
3. Kelvin to Centigrade
4. Hours and Minutes to Seconds
0. Exit
""")
    user = input("Enter a choice from the list\n>>")
    if user == '0':
        print('Bye bye!')
        break
    try:
        if user not in options.keys():
            raise ValueError('Please enter a valid option')

        print(options[user]())
        
    except ValueError as e:
        print(e)
        continue
# Out:
# 1. Feet to Meter
# 2. Pound to Kilo
# 3. Kelvin to Centigrade
# 4. Hours and Minutes to Seconds
# 0. Exit
#
# -269.15°C
# 1. Feet to Meter
# 2. Pound to Kilo
# 3. Kelvin to Centigrade
# 4. Hours and Minutes to Seconds
# 0. Exit
#
# 18780.00sec
# 1. Feet to Meter
# 2. Pound to Kilo
# 3. Kelvin to Centigrade
# 4. Hours and Minutes to Seconds
# 0. Exit
#
# 1.78m
# 1. Feet to Meter
# 2. Pound to Kilo
# 3. Kelvin to Centigrade
# 4. Hours and Minutes to Seconds
# 0. Exit
#
# Please enter a valid option
# 1. Feet to Meter
# 2. Pound to Kilo
# 3. Kelvin to Centigrade
# 4. Hours and Minutes to Seconds
# 0. Exit
#
# Please enter a valid option
# 1. Feet to Meter
# 2. Pound to Kilo
# 3. Kelvin to Centigrade
# 4. Hours and Minutes to Seconds
# 0. Exit
#
# 3.17kg
# 1. Feet to Meter
# 2. Pound to Kilo
# 3. Kelvin to Centigrade
# 4. Hours and Minutes to Seconds
# 0. Exit
#
# invalid literal for int() with base 10: 'yes'
# 1. Feet to Meter
# 2. Pound to Kilo
# 3. Kelvin to Centigrade
# 4. Hours and Minutes to Seconds
# 0. Exit
#
# 0.00sec
# 1. Feet to Meter
# 2. Pound to Kilo
# 3. Kelvin to Centigrade
# 4. Hours and Minutes to Seconds
# 0. Exit
#
# Bye bye!
